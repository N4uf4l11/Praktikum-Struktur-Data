# %% [markdown]
# <a href="https://colab.research.google.com/github/N4uf4l11/Praktikum-Struktur-Data/blob/main/Struktur_data_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Bubble sort
def bubble_sort(arr):
  n = len(arr)
  for i in range(n - 1):
    for j in range(n - i - 1):
      if arr[j] > arr[j + 1]:
        arr[j], arr[j + 1] = arr[j + 1], arr[j]
  return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy()) # Menggunakan copy agar data asli tidak berubah
print("Data sebelum sorting:", data)
print("Data setelah bubble sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah bubble sort: [11, 12, 22, 25, 34, 64, 90]

# %%
# Selection sort
def selection_sort(arr):
  n = len(arr)
  for i in range(n - 1):
    min_index = i
    for j in range(i + 1, n):
      if arr[j] < arr[min_index]:
        if arr[j] < arr[min_index]:
          min_index = j
      arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

# Contoh penggunaan
data = [64,25,12,22,11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah selection sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah selection sort: [11, 64, 25, 12, 22]

# %%
# Insertion sort
def insertion_sort(arr):
  n = len(arr)
  for i in range(1, n):
    key = arr[i]
    j = i - 1
    while j >= 0 and arr[j] > key:
      arr[j + 1] = arr[j]
      j -= 1
    arr[j + 1] = key
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah insertion sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah insertion sort: [34, 64, 25, 12, 22, 11, 90]

# %%
# Merge sort
def merge_sort(arr):
  if len(arr) > 1:
    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    merge_sort(left_half)
    merge_sort(right_half)

    i = j = k = 0

    while i < len(left_half) and j < len(right_half):
      if left_half[i] < right_half[j]:
        arr[k] = left_half[i]
        i += 1
      else:
        arr[k] = right_half[j]
        j += 1
        k += 1

    while i < len(left_half):
      arr[k] = left_half[i]
      i += 1
      k += 1

    while j < len(right_half):
      arr[k] = right_half[j]
      j += 1
      k += 1

  return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = merge_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah insertion sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah insertion sort: [11, 22, 11, 25, 64]

# %%
# Quick sort
def quick_sort(arr):
  if len(arr) <= 1:
    return arr

  pivot = arr[len(arr) // 2]
  left = [x for x in arr if x < pivot]
  middle = [x for x in arr if x == pivot]
  right = [x for x in arr if x > pivot]

  return quick_sort(left) + middle + quick_sort(right)

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah insertion sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah insertion sort: [11, 12, 22, 25, 64]

# %%
# Studi kasus rombel 02
def quick_sort(arr, key):
  if len(arr) <= 1:
    return arr

  pivot = arr[len(arr) // 2][key]
  left = [x for x in arr if x[key] < pivot]
  middle = [x for x in arr if x[key] == pivot]
  right = [x for x in arr if x[key] > pivot]

  return quick_sort(left, key) + middle + quick_sort(right, key)
data= [{"produk": "sepatu", "harga": 100000, "rating": 4},
       {"produk": "baju", "harga": 60000, "rating": 2},
       {"produk": "celana", "harga": 80000, "rating": 1},
       {"produk": "jaket", "harga": 160000, "rating": 3},
       ]
print("Data sebelum sorting:")
for a in data:
  print(a)
while True:
  print("="*30)
  cari = input("Cari data berdasarkan harga terendah/harga tertinggi/rating: ").lower()
  if cari == "harga terendah":
    pilihan = "harga"
    sorted_data = quick_sort(data, pilihan)
    for i in sorted_data:
      print(i)
  elif cari == "harga tertinggi":
    pilihan = "harga"
    sorted_data = quick_sort(data, pilihan)[::-1] # Menampilkan data reverse(terbalik)
    for i in sorted_data:
      print(i)
  elif cari == "rating":
    sorted_data = quick_sort(data, cari)[::-1]
    for i in sorted_data:
      print(i)
  else:
    print("data yang dimasukkan tidak valid")
  cari_lagi = input("Apakah anda ingin mencari data lagi(y/n): ").lower()
  if cari_lagi == "y":
    continue;
  elif cari_lagi == "n":
    print("Program selesai")
    break;
  else:
    print("input tidak terdeteksi")
    break;
# Out:
# Data sebelum sorting:
# {'produk': 'sepatu', 'harga': 100000, 'rating': 4}
# {'produk': 'baju', 'harga': 60000, 'rating': 2}
# {'produk': 'celana', 'harga': 80000, 'rating': 1}
# {'produk': 'jaket', 'harga': 160000, 'rating': 3}
# ==============================
# Cari data berdasarkan harga terendah/harga tertinggi/rating: harga tertinggi
# {'produk': 'jaket', 'harga': 160000, 'rating': 3}
# {'produk': 'sepatu', 'harga': 100000, 'rating': 4}
# {'produk': 'celana', 'harga': 80000, 'rating': 1}
# {'produk': 'baju', 'harga': 60000, 'rating': 2}
# Apakah anda ingin mencari data lagi(y/n): y
# ==============================
# Cari data berdasarkan harga terendah/harga tertinggi/rating: harga terendah
# {'produk': 'baju', 'harga': 60000, 'rating': 2}
# {'produk': 'celana', 'harga': 80000, 'rating': 1}
# {'produk': 'sepatu', 'harga': 100000, 'rating': 4}
# {'produk': 'jaket', 'harga': 160000, 'rating': 3}
# Apakah anda ingin mencari data lagi(y/n): y
# ==============================
# Cari data berdasarkan harga terendah/harga tertinggi/rating: rating
# {'produk': 'sepatu', 'harga': 100000, 'rating': 4}
# {'produk': 'jaket', 'harga': 160000, 'rating': 3}
# {'produk': 'baju', 'harga': 60000, 'rating': 2}
# {'produk': 'celana', 'harga': 80000, 'rating': 1}
# Apakah anda ingin mencari data lagi(y/n): n
# Program selesai
